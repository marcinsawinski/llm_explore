# %%
import requests as req

# %%
url = 'https://bazawiedzy.ue.poznan.pl/globalResultList.seam?q=&oa=false&r=author&tab=PEOPLE&conversationPropagation=begin&lang=en&qp=openAccess%3Dfalse'

# %%
 r = req.get(url)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n\n    <!--[if lte IE 10]>\n        <p class="chromeframe">Używana wersja przeglądarki jest <strong>przestarzała</strong>. Zaktualizuj lub wymień przeglądarkę na inną.</p>\n    <![endif]-->\n    <html lang="en"><head id="j_id_2_2"><link type="text/css" rel="stylesheet" href="/javax.faces.resource/theme.css.seam?ln=primefaces-omega" /><link rel="stylesheet" type="text/css" href="/javax.faces.resource/components.css.seam?ln=primefaces&amp;v=8.0" /><link rel="stylesheet" type="text/css" href="/javax.faces.resource/stylesheet/material/material.indigo-blue.min.css.seam?op_v=1693400891608" /><link rel="stylesheet" type="text/css" href="/javax.faces.resource/stylesheet/material/public_theme.css.seam?op_v=1693400891608" /><link rel="stylesheet" type="text/css" href="/javax.faces.resource/stylesheet/theme.css.seam?op_v=1693400891608" /><link rel="stylesheet" type="text/css" href="/javax.faces.resource/stylesheet/style_new.css.seam?op_v=1693400891608" /><link rel="stylesheet" 
# ...
